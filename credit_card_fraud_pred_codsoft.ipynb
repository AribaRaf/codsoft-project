# %% [markdown]
# importing dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
#load the data set to pandas dataframe
credit_card_data = pd.read_csv('/content/creditcard (1).csv')

# %%
#first 5 rows of data set and last 5 rows
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 5969  6634 -1.611463  0.190648  0.901715  1.531254 -1.535865  0.799245
# 5970  6635 -1.420272  1.449354  1.320110 -1.894320  0.913695  0.454601
# 5971  6637 -1.206696  0.284728  2.152053 -2.850437 -0.437285 -0.238376
# 5972  6644  1.067611  0.091006 -0.153917  0.704233  0.113894 -0.826866
# 5973  6645 -0.535272 -0.132299  2.180041  1.018303 -1.498819  0.529570
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 5969  1.513786  0.495829  0.200390  ...  0.211223  0.007477  1.026272
# 5970  0.894179 -0.385450  2.433841  ... -0.529027 -0.368394 -0.247773
# 5971 -0.333341  0.334679  2.870542  ...  0.039460  0.464476 -0.457193
# 5972  0.567690 -0.464181  0.957295  ... -0.476723 -1.410090 -0.037550
# 5973  0.420147  0.045445  1.543919  ...       NaN       NaN       NaN
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
#getting information about the dataset
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5974 entries, 0 to 5973
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    5974 non-null   int64
#  1   V1      5974 non-null   float64
#  2   V2      5974 non-null   float64
#  3   V3      5974 non-null   float64
#  4   V4      5974 non-null   float64
#  5   V5      5974 non-null   float64
#  6   V6      5974 non-null   float64
#  7   V7      5974 non-null   float64
#  8   V8      5974 non-null   float64
#  9   V9      5974 non-null   float64
#  10  V10     5974 non-null   float64
#  11  V11     5974 non-null   float64
#  12  V12     5974 non-null   float64
#  13  V13     5974 non-null   float64
#  14  V14     5974 non-null   float64
#  15  V15     5974 non-null   float64
#  16  V16     5974 non-null   float64
#  17  V17     5974 non-null   float64
#  18  V18     5973 non-null   float64
#  19  V19     5973 non-null   float64
# ...

# %%
#checking for missing values
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
#distribution of legit transactions and fraud
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    5970
# 1.0       3
# Name: count, dtype: int64

# %% [markdown]
# this dataset is highly unbalanced
#
# 0-- normal
# 1-- fraud
#
# separating the data for analysis

# %%
legit = credit_card_data[credit_card_data.Class==0]
fraud= credit_card_data[credit_card_data.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (5970, 31)
# (3, 31)

# %% [markdown]
# statistical measured of the data

# %%
legit.Amount.describe()
# Out:
# count    5970.000000
# mean       64.965707
# std       192.429839
# min         0.000000
# 25%         4.450000
# 50%        15.620000
# 75%        56.485000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
print(credit_card_data['Amount'].mean())
# Out:
# 65.06181148501591

# %%
credit_card_data['Amount'].fillna(credit_card_data['Amount'].mode()[0] , inplace= True)

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    0
# Class     1
# dtype: int64

# %%
print(credit_card_data['Class'].mode())
# Out:
# 0    0.0
# Name: Class, dtype: float64

# %%
credit_card_data['Class'].fillna(credit_card_data['Class'].mode()[0] , inplace= True)

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data['V14'].fillna(credit_card_data['V14'].mean(), inplace=True)

# %%
credit_card_data['V15'].fillna(credit_card_data['V15'].mean(), inplace=True)

# %%
credit_card_data['V18'].fillna(credit_card_data['V18'].mean(), inplace=True)
credit_card_data['V19'].fillna(credit_card_data['V19'].mean(), inplace=True)
credit_card_data['V20'].fillna(credit_card_data['V20'].mean(), inplace=True)
credit_card_data['V21'].fillna(credit_card_data['V21'].mean(), inplace=True)
credit_card_data['V22'].fillna(credit_card_data['V22'].mean(), inplace=True)
credit_card_data['V23'].fillna(credit_card_data['V23'].mean(), inplace=True)
credit_card_data['V24'].fillna(credit_card_data['V24'].mean(), inplace=True)
credit_card_data['V25'].fillna(credit_card_data['V25'].mean(), inplace=True)
credit_card_data['V26'].fillna(credit_card_data['V26'].mean(), inplace=True)
credit_card_data['V27'].fillna(credit_card_data['V27'].mean(), inplace=True)
credit_card_data['V28'].fillna(credit_card_data['V28'].mean(), inplace=True)

credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
legit.Amount.describe()
# Out:
# count    5970.000000
# mean       64.965707
# std       192.429839
# min         0.000000
# 25%         4.450000
# 50%        15.620000
# 75%        56.485000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      3.000000
# mean     256.310000
# std      264.880121
# min        0.000000
# 25%      119.965000
# 50%      239.930000
# 75%      384.465000
# max      529.000000
# Name: Amount, dtype: float64

# %%
#compare the values of both transacrions
credit_card_data.groupby('Class').mean()
# Out:
#               Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    2678.066488 -0.265010  0.285555  0.844803  0.102809  0.000707
# 1.0    1780.000000 -2.553039  0.184644 -0.293711  2.872264  0.005330
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.195476  0.018609 -0.039180  0.397664  ...  0.055426 -0.043268
# 1.0   -0.855718 -0.549831  0.308239 -1.093098  ...  0.599742  0.294921
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.161540 -0.036683  0.028985  0.089890 -0.040132  0.025238  0.006163
# 1.0   -0.177321  0.361160 -0.020311  0.056068 -0.170050  0.015979 -0.086847
#
#            Amount
# Class
# 0.0     64.954994
# 1.0    256.310000
#
# [2 rows x 30 columns]

# %% [markdown]
# under sampling
# build a sample data set with similar distribution of normal transactions and fraud transactions
# number of fraud trans =2
# number of legit trans = 1983

# %%
legit_sample = legit.sample(n = 500)

# %%
fraud_sample = fraud.sample(n=500 , replace= True)

# %% [markdown]
# concatenating 2 dataframes

# %%
new_dataset= pd.concat([legit_sample , fraud_sample], axis=0)

# %%
new_dataset.tail()
# Out:
#      Time        V1        V2        V3        V4        V5        V6  \
# 623   472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 541   406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 541   406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623   472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 541   406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
#
#            V7        V8        V9  ...       V21       V22       V23  \
# 623  0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 541 -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 541 -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623  0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 541 -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
#
#           V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 3872  3420 -0.884357  1.406706 -0.073748 -0.362845  0.588628  0.339749
# 5755  6117 -0.812460  0.280784  1.274797  1.310739 -0.580612  0.038560
# 2418  1985 -1.087323  0.413475  2.388311  0.799852  0.272501 -0.196010
# 1611  1252 -0.719833  0.920275  1.320202  0.713564 -0.452078  0.243132
# 3193  2777  1.218985 -1.075426 -1.154929 -2.965836  1.203556  3.158942
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 3872  0.305983 -0.390718 -0.518583  ...  0.816300 -0.248264 -0.103871
# 5755  1.597415 -0.195905  0.496023  ...  0.035528 -0.138674  0.769209
# 2418  0.592504 -0.059448 -0.186005  ... -0.019972  0.269333 -0.136500
# 1611  0.146169  0.608498 -0.749063  ...  0.041309  0.138041  0.085407
# 3193 -0.974587  0.844262  2.333557  ...  0.096690  0.375737 -0.298938
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    500
# 1.0    500
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#            Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    2674.438 -0.332030  0.328352  0.811005  0.045172 -0.043028  0.153446
# 1.0    1709.608 -2.552218  0.194797 -0.318977  2.903449  0.008011 -0.879614
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0   -0.018797 -0.138989  0.352357  ...  0.081721 -0.025526 -0.164336
# 1.0   -0.607377  0.341226 -1.140316  ...  0.606762  0.308792 -0.162395
#
#             V23       V24       V25       V26       V27       V28     Amount
# Class
# 0.0   -0.017959  0.037069  0.075229 -0.037694  0.053563  0.024102   66.58026
# 1.0    0.347648 -0.012429  0.059232 -0.157131  0.020505 -0.086916  251.44588
#
# [2 rows x 30 columns]

# %% [markdown]
# splitting the data into features and targets

# %%
x = new_dataset.drop(columns= 'Class', axis=1)
y  = new_dataset['Class']

# %%
print(x)
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 3872  3420 -0.884357  1.406706 -0.073748 -0.362845  0.588628  0.339749
# 5755  6117 -0.812460  0.280784  1.274797  1.310739 -0.580612  0.038560
# 2418  1985 -1.087323  0.413475  2.388311  0.799852  0.272501 -0.196010
# 1611  1252 -0.719833  0.920275  1.320202  0.713564 -0.452078  0.243132
# 3193  2777  1.218985 -1.075426 -1.154929 -2.965836  1.203556  3.158942
# ...    ...       ...       ...       ...       ...       ...       ...
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
#
#             V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(y)
# Out:
# 3872    0.0
# 5755    0.0
# 2418    0.0
# 1611    0.0
# 3193    0.0
#        ...
# 623     1.0
# 541     1.0
# 541     1.0
# 623     1.0
# 541     1.0
# Name: Class, Length: 1000, dtype: float64

# %% [markdown]
# split data into training and testing data

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y , test_size= 0.5 , stratify=y , random_state=2)

# %%
print(x.shape, x_train.shape , x_test.shape)
# Out:
# (1000, 30) (500, 30) (500, 30)

# %%
model = RandomForestClassifier(n_estimators=100, max_depth=5)
y_train = pd.concat([y_train, pd.Series([0] * (len(x_train_prediction) - len(y_train)))])

# %% [markdown]
# model building
# logistic regression

# %%
model.fit(x_train , y_train)
# Out:
# RandomForestClassifier(max_depth=5)

# %%
x_train_predictions = model.predict(x_train)
x_test_predictions = model.predict(x_test)

training_data_accuracy=accuracy_score(x_train_prediction , y_train)
print('the accuracy score of training data =', training_data_accuracy)
# Out:
# the accuracy score of training data = 0.506

# %%
x_test_predictions = model.predict(x_test)
test_data_accuracy=accuracy_score(x_test_predictions , y_test)
print('the accuracy score of test data =', test_data_accuracy)
# Out:
# the accuracy score of test data = 1.0
